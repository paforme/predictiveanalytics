# %% [markdown]
# # Linear Regression (Tensorflow)
# ## Chapter 5
# ### Predictive Analytics for the Modern Enterprise
#
# The notebook has been tested using the following pre-requisite:
#
# * Python V3.9.13 - https://www.python.org/
# * Tensorflow V2.11.0
# * Keras V2.11.0
# * Jupyter - V6.4.12 - https://jupyter.org/
# * Desktop computer - macOS Ventura V13.1

# %%
import numpy as np #Pre-processing                 
import pandas as pd #Pre-processing
import seaborn as sns #Visualization
import matplotlib.pyplot as plt #Visualization

import tensorflow as tflow #Predictive Analytics
from tensorflow import keras #Modeling and Predicting
from tensorflow.keras import layers #Model Building

from pandas import options, read_csv #Data import
# Out:
# 2023-02-24 19:26:23.522047: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Dataset sourced from: https://www.kaggle.com/datasets/quantbruce/real-estate-price-prediction

# %%
local_ds = '../Datasets/Real estate.csv' #Replace this with where you uncompressed the dataset
local_ds = read_csv(local_ds)
local_ds
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0       24.98298     121.54024                        37.9
# 1       24.98034     121.53951                        42.2
# 2       24.98746     121.54391                        47.3
# 3       24.98746     121.54391                        54.8
# 4       24.97937     121.54245                        43.1
# ..           ...           ...                         ...
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# 412     24.96674     121.54067                        52.5
# 413     24.97433     121.54310                        63.9
#
# [414 rows x 8 columns]

# %%
k_dataset = local_ds.copy()
k_dataset.pop('No')
k_dataset.pop('X1 transaction date')
k_dataset.pop('X5 latitude')
k_dataset.pop('X6 longitude')
k_dataset
# Out:
#      X2 house age  X3 distance to the nearest MRT station  \
# 0            32.0                                84.87882
# 1            19.5                               306.59470
# 2            13.3                               561.98450
# 3            13.3                               561.98450
# 4             5.0                               390.56840
# ..            ...                                     ...
# 409          13.7                              4082.01500
# 410           5.6                                90.45606
# 411          18.8                               390.96960
# 412           8.1                               104.81010
# 413           6.5                                90.45606
#
#      X4 number of convenience stores  Y house price of unit area
# 0                                 10                        37.9
# 1                                  9                        42.2
# 2                                  5                        47.3
# 3                                  5                        54.8
# 4                                  5                        43.1
# ..                               ...                         ...
# 409                                0                        15.4
# 410                                9                        50.0
# 411                                7                        40.6
# 412                                5                        52.5
# 413                                9                        63.9
#
# [414 rows x 4 columns]

# %%
k_training_ds = k_dataset.sample(frac=0.8, random_state=0) #Create training dataset as 80% of whole dataset
k_testing_ds = k_dataset.drop(k_training_ds.index) #Create test dataset by dropping training dataset indexes from whole dataset

# %%
# %matplotlib inline
sns.pairplot(k_training_ds, diag_kind='kde')

# %%
k_training_ds.describe()
# Out:
#        X2 house age  X3 distance to the nearest MRT station  \
# count    331.000000                              331.000000
# mean      17.652266                             1154.274016
# std       11.305017                             1319.156009
# min        0.000000                               23.382840
# 25%        9.950000                              289.324800
# 50%       16.100000                              515.112200
# 75%       27.550000                             1604.902500
# max       42.700000                             6488.021000
#
#        X4 number of convenience stores  Y house price of unit area
# count                       331.000000                  331.000000
# mean                          3.996979                   37.361329
# std                           2.964945                   13.763673
# min                           0.000000                    7.600000
# 25%                           1.000000                   26.950000
# 50%                           4.000000                   37.900000
# 75%                           6.000000                   45.500000
# max                          10.000000                  117.500000

# %%
k_training_ds = k_training_ds.copy() #Copy of the data
k_testing_ds = k_testing_ds.copy() #Copy of the data 

k_train_predict = k_training_ds.pop('Y house price of unit area') #Separate the features and labels (predictors and predicted)
k_test_predict = k_testing_ds.pop('Y house price of unit area') #Separate the features and labels (predictors and predicted)

# %%
k_training_ds.describe().transpose()[['mean', 'std']]
# Out:
#                                                mean          std
# X2 house age                              17.652266    11.305017
# X3 distance to the nearest MRT station  1154.274016  1319.156009
# X4 number of convenience stores            3.996979     2.964945

# %% [markdown]
# ### What is normalization ?/?
#
# Normalization is a data preparation technique that is frequently used in machine learning. The process of transforming the columns in a dataset to the same scale is referred to as normalization. Every dataset does not need to be normalized for machine learning. It is only required when the ranges of characteristics are different.
#
# Consider a data collection that includes two characteristics: age and income. Where the age spans from 0 to 80 years old, and the income extends from 0 to 80,000 dollars and up. Income is roughly 1,000 times that of age. As a result, the ranges of these two characteristics are vastly different.
#
# Because of its bigger value, the attributed income will organically influence the conclusion more when we undertake further analysis, such as multivariate linear regression. However, this does not necessarily imply that it is a better predictor. As a result, we normalize the data so that all of the variables are in the same range.
#
# We normalize training data to solve the model learning challenge. We make sure that the various features have similar value ranges (feature scaling) so that gradient descents can converge faster.
#
#
# ---
#
#
# It is good practice to normalize features that use different scales and ranges.
#
# One reason this is important is because the features are multiplied by the model weights. So, the scale of the outputs and the scale of the gradients are affected by the scale of the inputs.
#
# Although a model might converge without feature normalization, normalization makes training much more stable.
#
# Note: There is no advantage to normalizing the one-hot features—it is done here for simplicity. For more details on how to use the preprocessing layers, refer to the Working with preprocessing layers guide and the Classify structured data using Keras preprocessing layers tutorial.

# %%
normalizer = tflow.keras.layers.Normalization(axis=-1) #A preprocessing layer which normalizes continuous features

# %% [markdown]
# This layer will shift and scale inputs into a distribution centered around 0 with standard deviation 1. It accomplishes this by precomputing the mean and variance of the data, and calling (input - mean) / sqrt(var) at runtime.
#
# axis - Integer, tuple of integers, or None. The axis or axes that should have a separate mean and variance for each index in the shape. For example, if shape is (None, 5) and axis=1, the layer will track 5 separate mean and variance values for the last axis. If axis is set to None, the layer will normalize all elements in the input by a scalar mean and variance. Defaults to -1, where the last axis of the input is assumed to be a feature dimension and is normalized per index. Note that in the specific case of batched scalar inputs where the only axis is the batch axis, the default will normalize each index in the batch separately. In this case, consider passing axis=None.

# %%
normalizer.adapt(np.array(k_training_ds))
# Out:
# 2023-02-24 19:26:30.170659: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Computes the mean and variance of values in a dataset.

# %%
print(normalizer.mean)
# Out:
# tf.Tensor([[  17.652266  1154.2739       3.9969788]], shape=(1, 3), dtype=float32)

# %%
print('Original: ', np.array(k_training_ds[0:9]))
print('\nNormalized: ', normalizer(np.array(k_training_ds[0:9])).numpy())
# Out:
# Original:  [[1.030000e+01 2.114473e+02 1.000000e+00]
#  [2.400000e+01 4.527687e+03 0.000000e+00]
#  [3.450000e+01 3.249419e+02 6.000000e+00]
#  [2.560000e+01 4.519690e+03 0.000000e+00]
#  [1.440000e+01 1.699803e+02 1.000000e+00]
#  [3.660000e+01 4.888193e+02 8.000000e+00]
#  [3.580000e+01 1.707311e+02 7.000000e+00]
#  [3.480000e+01 4.052134e+02 1.000000e+00]
#  [1.050000e+01 2.791726e+02 7.000000e+00]]
#
# Normalized:  [[-0.6513389  -0.71580166 -1.0123346 ]
#  [ 0.56234723  2.5611227  -1.3501196 ]
#  [ 1.4925447  -0.62963563  0.67659056]
#  [ 0.70409167  2.5550513  -1.3501196 ]
#  [-0.288119   -0.74728376 -1.0123346 ]
#  [ 1.678584   -0.50521857  1.3521606 ]
#  [ 1.6077119  -0.74671376  1.0143756 ]
#  [ 1.5191216  -0.56869286 -1.0123346 ]
#  [-0.63362086 -0.66438407  1.0143756 ]]

# %% [markdown]
# input_shape=[1,] = we are passing only 1 features so input tensor has a shape 1,

# %% [markdown]
# units = 1 - Positive integer, dimensionality of the output space.

# %%
linear_model = tflow.keras.Sequential() #Define the model
linear_model.add(normalizer) #Add a pre-processing layer
linear_model.add(layers.Dense(1)) #Apply linear transformation via a dense layer that produces 1 output

# %%
linear_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 3)                7
#  n)
#
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 11
# Trainable params: 4
# Non-trainable params: 7
# _________________________________________________________________

# %%
linear_model.compile(   #compile the model to define the optimizer and the loss 
    optimizer=tflow.keras.optimizers.Adam(learning_rate=0.1),
    loss='mean_absolute_error')

# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import tensorflow as tf
import datetime

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
linear_model.fit(   
    k_training_ds,
    k_train_predict,
    epochs=100,
    verbose=1, 
    validation_split = 0.2,
    callbacks=[tensorboard_callback])  # Calculate validation results on 20% of the training data.
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 25ms/step - loss: 37.3335 - accuracy: 0.0000e+00 - val_loss: 35.2268 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 9/9 [==============================] - 0s 7ms/step - loss: 36.4166 - accuracy: 0.0000e+00 - val_loss: 34.3395 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 9/9 [==============================] - 0s 7ms/step - loss: 35.5109 - accuracy: 0.0000e+00 - val_loss: 33.4690 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 9/9 [==============================] - 0s 7ms/step - loss: 34.6007 - accuracy: 0.0000e+00 - val_loss: 32.6016 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 9/9 [==============================] - 0s 7ms/step - loss: 33.6875 - accuracy: 0.0000e+00 - val_loss: 31.7379 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 9/9 [==============================] - 0s 7ms/step - loss: 32.7834 - accuracy: 0.0000e+00 - val_loss: 30.8798 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 9/9 [==============================] - 0s 8ms/step - loss: 31.8641 - accuracy: 0.0000e+00 - val_loss: 30.0453 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 9/9 [==============================] - 0s 7ms/step - loss: 30.9519 - accuracy: 0.0000e+00 - val_loss: 29.2316 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 9/9 [==============================] - 0s 8ms/step - loss: 30.0405 - accuracy: 0.0000e+00 - val_loss: 28.3833 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 9/9 [==============================] - 0s 8ms/step - loss: 29.1349 - accuracy: 0.0000e+00 - val_loss: 27.5527 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 9/9 [==============================] - 0s 8ms/step - loss: 28.2323 - accuracy: 0.0000e+00 - val_loss: 26.6947 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 9/9 [==============================] - 0s 8ms/step - loss: 27.3292 - accuracy: 0.0000e+00 - val_loss: 25.8830 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 9/9 [==============================] - 0s 7ms/step - loss: 26.4278 - accuracy: 0.0000e+00 - val_loss: 25.0469 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 9/9 [==============================] - 0s 7ms/step - loss: 25.5265 - accuracy: 0.0000e+00 - val_loss: 24.1951 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 9/9 [==============================] - 0s 7ms/step - loss: 24.6189 - accuracy: 0.0000e+00 - val_loss: 23.3682 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 9/9 [==============================] - 0s 7ms/step - loss: 23.7114 - accuracy: 0.0000e+00 - val_loss: 22.5284 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 9/9 [==============================] - 0s 8ms/step - loss: 22.8262 - accuracy: 0.0000e+00 - val_loss: 21.7054 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 9/9 [==============================] - 0s 15ms/step - loss: 21.9285 - accuracy: 0.0000e+00 - val_loss: 20.8817 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 9/9 [==============================] - 0s 8ms/step - loss: 21.0118 - accuracy: 0.0000e+00 - val_loss: 20.0470 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 9/9 [==============================] - 0s 8ms/step - loss: 20.1236 - accuracy: 0.0000e+00 - val_loss: 19.2463 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 9/9 [==============================] - 0s 7ms/step - loss: 19.2172 - accuracy: 0.0000e+00 - val_loss: 18.4422 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 9/9 [==============================] - 0s 7ms/step - loss: 18.3221 - accuracy: 0.0000e+00 - val_loss: 17.6392 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 9/9 [==============================] - 0s 7ms/step - loss: 17.4265 - accuracy: 0.0000e+00 - val_loss: 16.8374 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 9/9 [==============================] - 0s 7ms/step - loss: 16.5654 - accuracy: 0.0000e+00 - val_loss: 16.0326 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 9/9 [==============================] - 0s 7ms/step - loss: 15.6843 - accuracy: 0.0000e+00 - val_loss: 15.2142 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 9/9 [==============================] - 0s 7ms/step - loss: 14.8386 - accuracy: 0.0000e+00 - val_loss: 14.4426 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 9/9 [==============================] - 0s 7ms/step - loss: 13.9980 - accuracy: 0.0000e+00 - val_loss: 13.7025 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 9/9 [==============================] - 0s 7ms/step - loss: 13.1560 - accuracy: 0.0000e+00 - val_loss: 12.9048 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 9/9 [==============================] - 0s 8ms/step - loss: 12.3871 - accuracy: 0.0000e+00 - val_loss: 12.0948 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 9/9 [==============================] - 0s 7ms/step - loss: 11.6109 - accuracy: 0.0000e+00 - val_loss: 11.3306 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 9/9 [==============================] - 0s 7ms/step - loss: 10.8793 - accuracy: 0.0000e+00 - val_loss: 10.6371 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 9/9 [==============================] - 0s 8ms/step - loss: 10.1523 - accuracy: 0.0000e+00 - val_loss: 9.9865 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 9/9 [==============================] - 0s 8ms/step - loss: 9.4855 - accuracy: 0.0000e+00 - val_loss: 9.3718 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 9/9 [==============================] - 0s 8ms/step - loss: 8.8654 - accuracy: 0.0000e+00 - val_loss: 8.8685 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 9/9 [==============================] - 0s 7ms/step - loss: 8.3040 - accuracy: 0.0000e+00 - val_loss: 8.4443 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 9/9 [==============================] - 0s 7ms/step - loss: 7.8407 - accuracy: 0.0000e+00 - val_loss: 8.0970 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 9/9 [==============================] - 0s 6ms/step - loss: 7.4400 - accuracy: 0.0000e+00 - val_loss: 7.7991 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 9/9 [==============================] - 0s 6ms/step - loss: 7.0909 - accuracy: 0.0000e+00 - val_loss: 7.5824 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.8288 - accuracy: 0.0000e+00 - val_loss: 7.4221 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.6182 - accuracy: 0.0000e+00 - val_loss: 7.2665 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.4717 - accuracy: 0.0000e+00 - val_loss: 7.1407 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.3749 - accuracy: 0.0000e+00 - val_loss: 7.0584 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.3014 - accuracy: 0.0000e+00 - val_loss: 7.0303 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.2422 - accuracy: 0.0000e+00 - val_loss: 7.0129 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.2047 - accuracy: 0.0000e+00 - val_loss: 6.9978 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1777 - accuracy: 0.0000e+00 - val_loss: 6.9891 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1643 - accuracy: 0.0000e+00 - val_loss: 7.0019 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1376 - accuracy: 0.0000e+00 - val_loss: 6.9955 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1254 - accuracy: 0.0000e+00 - val_loss: 7.0095 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1365 - accuracy: 0.0000e+00 - val_loss: 7.0258 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1360 - accuracy: 0.0000e+00 - val_loss: 7.0060 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1298 - accuracy: 0.0000e+00 - val_loss: 6.9858 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1174 - accuracy: 0.0000e+00 - val_loss: 6.9766 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1169 - accuracy: 0.0000e+00 - val_loss: 6.9870 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1106 - accuracy: 0.0000e+00 - val_loss: 7.0075 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1188 - accuracy: 0.0000e+00 - val_loss: 7.0295 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1222 - accuracy: 0.0000e+00 - val_loss: 7.0166 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1072 - accuracy: 0.0000e+00 - val_loss: 7.0100 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1085 - accuracy: 0.0000e+00 - val_loss: 7.0009 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1094 - accuracy: 0.0000e+00 - val_loss: 6.9998 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1169 - accuracy: 0.0000e+00 - val_loss: 7.0023 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1196 - accuracy: 0.0000e+00 - val_loss: 7.0054 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1131 - accuracy: 0.0000e+00 - val_loss: 7.0189 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1199 - accuracy: 0.0000e+00 - val_loss: 7.0273 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1206 - accuracy: 0.0000e+00 - val_loss: 7.0258 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1149 - accuracy: 0.0000e+00 - val_loss: 7.0186 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1105 - accuracy: 0.0000e+00 - val_loss: 7.0141 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1148 - accuracy: 0.0000e+00 - val_loss: 7.0053 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1248 - accuracy: 0.0000e+00 - val_loss: 7.0074 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1155 - accuracy: 0.0000e+00 - val_loss: 7.0085 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1071 - accuracy: 0.0000e+00 - val_loss: 7.0003 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1081 - accuracy: 0.0000e+00 - val_loss: 7.0002 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1129 - accuracy: 0.0000e+00 - val_loss: 7.0043 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1103 - accuracy: 0.0000e+00 - val_loss: 7.0034 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1076 - accuracy: 0.0000e+00 - val_loss: 7.0008 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1064 - accuracy: 0.0000e+00 - val_loss: 6.9967 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1134 - accuracy: 0.0000e+00 - val_loss: 6.9992 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1097 - accuracy: 0.0000e+00 - val_loss: 7.0055 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1117 - accuracy: 0.0000e+00 - val_loss: 7.0015 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1156 - accuracy: 0.0000e+00 - val_loss: 7.0265 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1148 - accuracy: 0.0000e+00 - val_loss: 7.0149 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1182 - accuracy: 0.0000e+00 - val_loss: 6.9978 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1209 - accuracy: 0.0000e+00 - val_loss: 6.9983 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1223 - accuracy: 0.0000e+00 - val_loss: 7.0183 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1168 - accuracy: 0.0000e+00 - val_loss: 7.0133 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1173 - accuracy: 0.0000e+00 - val_loss: 7.0153 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1085 - accuracy: 0.0000e+00 - val_loss: 7.0047 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1133 - accuracy: 0.0000e+00 - val_loss: 7.0065 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1122 - accuracy: 0.0000e+00 - val_loss: 7.0072 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 9/9 [==============================] - 0s 6ms/step - loss: 6.1139 - accuracy: 0.0000e+00 - val_loss: 6.9957 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1127 - accuracy: 0.0000e+00 - val_loss: 7.0005 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1096 - accuracy: 0.0000e+00 - val_loss: 7.0042 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1151 - accuracy: 0.0000e+00 - val_loss: 7.0226 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1143 - accuracy: 0.0000e+00 - val_loss: 7.0118 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1106 - accuracy: 0.0000e+00 - val_loss: 7.0046 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1093 - accuracy: 0.0000e+00 - val_loss: 7.0082 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1174 - accuracy: 0.0000e+00 - val_loss: 7.0016 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1089 - accuracy: 0.0000e+00 - val_loss: 7.0127 - val_accuracy: 0.0000e+00
# Epoch 99/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1137 - accuracy: 0.0000e+00 - val_loss: 7.0191 - val_accuracy: 0.0000e+00
# Epoch 100/100
# 9/9 [==============================] - 0s 7ms/step - loss: 6.1141 - accuracy: 0.0000e+00 - val_loss: 7.0147 - val_accuracy: 0.0000e+00

# %%
# %tensorboard --logdir logs/fit
# Out:
#       <iframe id="tensorboard-frame-4c2940c9539e85ec" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4c2940c9539e85ec");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
evaluation =  linear_model.evaluate(k_testing_ds, k_test_predict, verbose=1)
print(evaluation)
# Out:
# 3/3 [==============================] - 0s 2ms/step - loss: 6.6714
# 6.6713972091674805

# %%
predictions = linear_model.predict(k_testing_ds[5:8])
print(predictions)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[45.694748]
#  [42.129364]
#  [35.750698]]

# %%
print(k_test_predict[5:8])
# Out:
# 38    47.7
# 39    46.2
# 42    34.7
# Name: Y house price of unit area, dtype: float64
