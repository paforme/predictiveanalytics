# %% [markdown]
# # Deep Neural Networks (Tensorflow)
# ## Chapter 6
# ### Predictive Analytics for the Modern Enterprise
#
# The notebook has been tested using the following pre-requisite:
#
# * Python V3.9.13 - https://www.python.org/
# * Tensorflow V2.11.0
# * Keras V2.11.0
# * Jupyter - V6.4.12 - https://jupyter.org/
# * Desktop computer - macOS Ventura V13.1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tflow
from tensorflow import keras
from tensorflow.keras import layers

from pandas import options, read_csv
# Out:
# 2024-02-11 11:18:30.999416: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# This data is sourced from https://archive.ics.uci.edu/ml/datasets/abalone
#
# You can download a copy of the data at: https://github.com/paforme/predictiveanalytics/blob/main/Chapter5/Datasets/abalone.data

# %%
local_ds = './Datasets/abalone.data' #Change this to where you downloaded the data. 
abalone = read_csv(local_ds)
abalone
# Out:
#      sex  length  diameter  height  whole_weight  shuckled_weight  \
# 0      M   0.455     0.365   0.095        0.5140           0.2245
# 1      M   0.350     0.265   0.090        0.2255           0.0995
# 2      F   0.530     0.420   0.135        0.6770           0.2565
# 3      M   0.440     0.365   0.125        0.5160           0.2155
# 4      I   0.330     0.255   0.080        0.2050           0.0895
# ...   ..     ...       ...     ...           ...              ...
# 4172   F   0.565     0.450   0.165        0.8870           0.3700
# 4173   M   0.590     0.440   0.135        0.9660           0.4390
# 4174   M   0.600     0.475   0.205        1.1760           0.5255
# 4175   F   0.625     0.485   0.150        1.0945           0.5310
# 4176   M   0.710     0.555   0.195        1.9485           0.9455
#
#       viscera_weight  shell_weight  rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
k_dataset = abalone.copy() #Make a copy of the dataset
k_dataset = pd.get_dummies(k_dataset) # Do one-hot encoding of categorical fields
k_dataset
# Out:
#       length  diameter  height  whole_weight  shuckled_weight  viscera_weight  \
# 0      0.455     0.365   0.095        0.5140           0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255           0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770           0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160           0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050           0.0895          0.0395
# ...      ...       ...     ...           ...              ...             ...
# 4172   0.565     0.450   0.165        0.8870           0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660           0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760           0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945           0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485           0.9455          0.3765
#
#       shell_weight  rings  sex_F  sex_I  sex_M
# 0           0.1500     15      0      0      1
# 1           0.0700      7      0      0      1
# 2           0.2100      9      1      0      0
# 3           0.1550     10      0      0      1
# 4           0.0550      7      0      1      0
# ...            ...    ...    ...    ...    ...
# 4172        0.2490     11      1      0      0
# 4173        0.2605     10      0      0      1
# 4174        0.3080      9      0      0      1
# 4175        0.2960     10      1      0      0
# 4176        0.4950     12      0      0      1
#
# [4177 rows x 11 columns]

# %%
k_dataset.isna().sum() #null values have been removed
# Out:
# length             0
# diameter           0
# height             0
# whole_weight       0
# shuckled_weight    0
# viscera_weight     0
# shell_weight       0
# rings              0
# sex_F              0
# sex_I              0
# sex_M              0
# dtype: int64

# %%
k_training_ds = k_dataset.sample(frac=0.8, random_state=0) #Create training dataset as 80% of whole dataset
k_testing_ds = k_dataset.drop(k_training_ds.index) #Create test dataset by dropping training dataset indexes from whole dataset
k_training_ds
# Out:
#       length  diameter  height  whole_weight  shuckled_weight  viscera_weight  \
# 668    0.550     0.425   0.155        0.9175           0.2775          0.2430
# 1580   0.500     0.400   0.120        0.6160           0.2610          0.1430
# 3784   0.620     0.480   0.155        1.2555           0.5270          0.3740
# 463    0.220     0.165   0.055        0.0545           0.0215          0.0120
# 2615   0.645     0.500   0.175        1.5105           0.6735          0.3755
# ...      ...       ...     ...           ...              ...             ...
# 1659   0.600     0.480   0.180        1.0645           0.4495          0.2455
# 3306   0.410     0.300   0.115        0.2595           0.0970          0.0515
# 920    0.415     0.330   0.090        0.3595           0.1700          0.0810
# 1433   0.370     0.270   0.095        0.2320           0.1325          0.0410
# 3666   0.575     0.440   0.150        0.9830           0.4860          0.2150
#
#       shell_weight  rings  sex_F  sex_I  sex_M
# 668         0.3350     13      0      0      1
# 1580        0.1935      8      0      1      0
# 3784        0.3175     11      0      0      1
# 463         0.0200      5      0      1      0
# 2615        0.3775     12      0      0      1
# ...            ...    ...    ...    ...    ...
# 1659        0.3250     10      1      0      0
# 3306        0.0800     10      0      1      0
# 920         0.0900      6      0      1      0
# 1433        0.0615      6      0      1      0
# 3666        0.2390      8      0      1      0
#
# [3342 rows x 11 columns]

# %%
# %matplotlib inline
sns.pairplot(k_training_ds, diag_kind='kde')

# %%
k_training_ds.describe().transpose()
# Out:
#                   count      mean       std     min       25%       50%  \
# length           3342.0  0.524065  0.119299  0.0750  0.450000   0.54500
# diameter         3342.0  0.407723  0.098505  0.0550  0.350000   0.42500
# height           3342.0  0.139455  0.038818  0.0000  0.115000   0.14000
# whole_weight     3342.0  0.827379  0.488588  0.0020  0.440125   0.79975
# shuckled_weight  3342.0  0.358846  0.221154  0.0010  0.185625   0.33600
# viscera_weight   3342.0  0.180795  0.109585  0.0005  0.093500   0.17050
# shell_weight     3342.0  0.238099  0.137449  0.0015  0.130000   0.23375
# rings            3342.0  9.916517  3.180008  1.0000  8.000000  10.00000
# sex_F            3342.0  0.313884  0.464139  0.0000  0.000000   0.00000
# sex_I            3342.0  0.325554  0.468651  0.0000  0.000000   0.00000
# sex_M            3342.0  0.360563  0.480236  0.0000  0.000000   0.00000
#
#                        75%      max
# length            0.615000   0.8150
# diameter          0.480000   0.6500
# height            0.165000   0.5150
# whole_weight      1.145000   2.8255
# shuckled_weight   0.499500   1.3510
# viscera_weight    0.253000   0.7600
# shell_weight      0.326375   0.8970
# rings            11.000000  29.0000
# sex_F             1.000000   1.0000
# sex_I             1.000000   1.0000
# sex_M             1.000000   1.0000

# %%
k_training_ds = k_training_ds.copy() #Copy of the data
k_testing_ds = k_testing_ds.copy() #Copy of the data 

k_train_predict = k_training_ds.pop('rings') #Data for rings ONLY (to be predicted) <- Removed from features
k_test_predict = k_testing_ds.pop('rings') #Data for rings ONLY(to be predicted) <- Removed from features

# %%
k_training_ds.describe().transpose()[['mean', 'std']]
# Out:
#                      mean       std
# length           0.524065  0.119299
# diameter         0.407723  0.098505
# height           0.139455  0.038818
# whole_weight     0.827379  0.488588
# shuckled_weight  0.358846  0.221154
# viscera_weight   0.180795  0.109585
# shell_weight     0.238099  0.137449
# sex_F            0.313884  0.464139
# sex_I            0.325554  0.468651
# sex_M            0.360563  0.480236

# %%
normalizer = tflow.keras.layers.Normalization(axis=1) #A preprocessing layer which normalizes continuous features

# %%
normalizer.adapt(np.array(k_training_ds))

# %% [markdown]
# Computes the mean and variance of values in a dataset.

# %%
print(normalizer.mean.numpy())
# Out:
# [[0.5240649  0.40772295 0.13945538 0.82737887 0.35884637 0.18079533
#   0.2380991  0.313884   0.3255536  0.36056268]]

# %% [markdown]
# input_shape=[1,] = we are passing only 1 features so input tensor has a shape 1,

# %% [markdown]
# units = 1 - Positive integer, dimensionality of the output space.

# %%
dnn_model = tflow.keras.Sequential() #Define the model
dnn_model.add(normalizer) #Add a pre-processing layer
dnn_model.add(layers.Dense(64, activation='relu')) #non linear layer 1
dnn_model.add(layers.Dense(64, activation='relu')) #non linear layer 2
dnn_model.add(layers.Dense(1)) #Apply linear transformation via a dense layer that produces 1 output

# %%
dnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 10)               21
#  n)
#
#  dense (Dense)               (None, 64)                704
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,950
# Trainable params: 4,929
# Non-trainable params: 21
# _________________________________________________________________

# %%
dnn_model.compile(   #compile the model to define the optimizer and the loss 
    optimizer=tflow.keras.optimizers.Adam(learning_rate=0.001),
    loss='mean_absolute_error')

# %%
# %load_ext tensorboard

# %%
import tensorflow as tf
import datetime

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

dnn_model.fit(   
    k_training_ds,
    k_train_predict,
    epochs=100,
    verbose=1, 
    validation_split = 0.2,
    callbacks=[tensorboard_callback])  # Calculate validation results on 20% of the training data.
# Out:
# Epoch 1/100
# 84/84 [==============================] - 1s 4ms/step - loss: 6.1545 - val_loss: 3.3947
# Epoch 2/100
# 84/84 [==============================] - 0s 2ms/step - loss: 2.2809 - val_loss: 1.6737
# Epoch 3/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.6147 - val_loss: 1.6122
# Epoch 4/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.5786 - val_loss: 1.5765
# Epoch 5/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.5511 - val_loss: 1.5547
# Epoch 6/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.5302 - val_loss: 1.5868
# Epoch 7/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.5304 - val_loss: 1.5429
# Epoch 8/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.5088 - val_loss: 1.5567
# Epoch 9/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.5091 - val_loss: 1.5375
# Epoch 10/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4832 - val_loss: 1.5219
# Epoch 11/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4829 - val_loss: 1.5154
# Epoch 12/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4748 - val_loss: 1.5126
# Epoch 13/100
# 84/84 [==============================] - 0s 3ms/step - loss: 1.4702 - val_loss: 1.5089
# Epoch 14/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4625 - val_loss: 1.5172
# Epoch 15/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4531 - val_loss: 1.5249
# Epoch 16/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4614 - val_loss: 1.4899
# Epoch 17/100
# 84/84 [==============================] - 0s 3ms/step - loss: 1.4578 - val_loss: 1.4994
# Epoch 18/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4457 - val_loss: 1.5190
# Epoch 19/100
# 84/84 [==============================] - 0s 3ms/step - loss: 1.4451 - val_loss: 1.4956
# Epoch 20/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4453 - val_loss: 1.4959
# Epoch 21/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4408 - val_loss: 1.5046
# Epoch 22/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4426 - val_loss: 1.4915
# Epoch 23/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4277 - val_loss: 1.5143
# Epoch 24/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4394 - val_loss: 1.5219
# Epoch 25/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4441 - val_loss: 1.4934
# Epoch 26/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4417 - val_loss: 1.5205
# Epoch 27/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4471 - val_loss: 1.5509
# Epoch 28/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4287 - val_loss: 1.5167
# Epoch 29/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4283 - val_loss: 1.5127
# Epoch 30/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4319 - val_loss: 1.5242
# Epoch 31/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4275 - val_loss: 1.4823
# Epoch 32/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4301 - val_loss: 1.4916
# Epoch 33/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4208 - val_loss: 1.5541
# Epoch 34/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4218 - val_loss: 1.5076
# Epoch 35/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4273 - val_loss: 1.4897
# Epoch 36/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4140 - val_loss: 1.5300
# Epoch 37/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4209 - val_loss: 1.4802
# Epoch 38/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4154 - val_loss: 1.5031
# Epoch 39/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4174 - val_loss: 1.5055
# Epoch 40/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4186 - val_loss: 1.4956
# Epoch 41/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4106 - val_loss: 1.4940
# Epoch 42/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4100 - val_loss: 1.5034
# Epoch 43/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4183 - val_loss: 1.4978
# Epoch 44/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4230 - val_loss: 1.4903
# Epoch 45/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4125 - val_loss: 1.4963
# Epoch 46/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4141 - val_loss: 1.5294
# Epoch 47/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4051 - val_loss: 1.4801
# Epoch 48/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4022 - val_loss: 1.4827
# Epoch 49/100
# 84/84 [==============================] - 0s 3ms/step - loss: 1.4048 - val_loss: 1.4917
# Epoch 50/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4053 - val_loss: 1.4954
# Epoch 51/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4004 - val_loss: 1.5128
# Epoch 52/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4082 - val_loss: 1.5258
# Epoch 53/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4035 - val_loss: 1.5164
# Epoch 54/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4053 - val_loss: 1.4972
# Epoch 55/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4102 - val_loss: 1.4998
# Epoch 56/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4023 - val_loss: 1.5003
# Epoch 57/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4144 - val_loss: 1.4916
# Epoch 58/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4211 - val_loss: 1.5015
# Epoch 59/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4045 - val_loss: 1.4982
# Epoch 60/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4001 - val_loss: 1.4869
# Epoch 61/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4004 - val_loss: 1.5066
# Epoch 62/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4061 - val_loss: 1.5023
# Epoch 63/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4010 - val_loss: 1.4896
# Epoch 64/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3930 - val_loss: 1.4829
# Epoch 65/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4000 - val_loss: 1.4755
# Epoch 66/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3941 - val_loss: 1.4945
# Epoch 67/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4078 - val_loss: 1.5055
# Epoch 68/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3979 - val_loss: 1.5122
# Epoch 69/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4006 - val_loss: 1.4968
# Epoch 70/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3874 - val_loss: 1.4861
# Epoch 71/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3991 - val_loss: 1.5026
# Epoch 72/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.4066 - val_loss: 1.4876
# Epoch 73/100
# 84/84 [==============================] - 0s 3ms/step - loss: 1.3979 - val_loss: 1.4999
# Epoch 74/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3834 - val_loss: 1.4989
# Epoch 75/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3917 - val_loss: 1.4920
# Epoch 76/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3856 - val_loss: 1.5123
# Epoch 77/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3865 - val_loss: 1.4862
# Epoch 78/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3867 - val_loss: 1.4774
# Epoch 79/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3856 - val_loss: 1.4913
# Epoch 80/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3911 - val_loss: 1.5077
# Epoch 81/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3783 - val_loss: 1.5574
# Epoch 82/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3755 - val_loss: 1.4971
# Epoch 83/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3746 - val_loss: 1.4911
# Epoch 84/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3802 - val_loss: 1.5030
# Epoch 85/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3979 - val_loss: 1.4927
# Epoch 86/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3827 - val_loss: 1.5167
# Epoch 87/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3902 - val_loss: 1.4979
# Epoch 88/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3824 - val_loss: 1.4943
# Epoch 89/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3775 - val_loss: 1.5192
# Epoch 90/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3750 - val_loss: 1.4900
# Epoch 91/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3879 - val_loss: 1.5128
# Epoch 92/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3833 - val_loss: 1.4857
# Epoch 93/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3730 - val_loss: 1.4815
# Epoch 94/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3732 - val_loss: 1.4960
# Epoch 95/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3734 - val_loss: 1.5063
# Epoch 96/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3764 - val_loss: 1.4856
# Epoch 97/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3717 - val_loss: 1.4869
# Epoch 98/100
# 84/84 [==============================] - 0s 3ms/step - loss: 1.3697 - val_loss: 1.5039
# Epoch 99/100
# 84/84 [==============================] - 0s 3ms/step - loss: 1.3671 - val_loss: 1.4925
# Epoch 100/100
# 84/84 [==============================] - 0s 2ms/step - loss: 1.3859 - val_loss: 1.4907

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 39562), started 0:01:14 ago. (Use '!kill 39562' to kill it.)
#       <iframe id="tensorboard-frame-65f24d589a891ca6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-65f24d589a891ca6");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
evaluation =  dnn_model.evaluate(k_testing_ds, k_test_predict, verbose=1)
print(evaluation)
# Out:
# 27/27 [==============================] - 0s 1ms/step - loss: 1.5735
# 1.5734785795211792

# %%
predictions = dnn_model.predict(k_testing_ds[5:8])
print(predictions)
# Out:
# 1/1 [==============================] - 0s 84ms/step
# [[ 9.918337 ]
#  [10.8706665]
#  [11.225043 ]]

# %%
print(k_test_predict[5:8])
# Out:
# 24    10
# 25    11
# 26    11
# Name: rings, dtype: int64
